# %%
import pandas as pd
import seaborn as sns

# %%
import scipy as stats

# %%
from sklearn.datasets import load_iris

# %%
test = pd.read_csv("/home/shakiba/Downloads/data_mining/Smartphone.csv")

# %%
import matplotlib.pyplot as plt

# %%
test
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
df = pd.DataFrame(test)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
df[(df['int_memory']>=11) & (df['blue']==1)]
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 4              1821     1          1.2         0  13       1          44
# 8              1445     1          0.5         0   0       0          53
# 11             1520     1          2.2         0   5       1          33
# ...             ...   ...          ...       ...  ..     ...         ...
# 1990           1617     1          2.4         0   8       1          36
# 1992            674     1          2.9         1   1       0          21
# 1993           1467     1          0.5         0   0       0          18
# 1996           1965     1          2.6         1   0       0          39
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
df[df['fc']==df['fc'].max()]
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1705           1290     1          1.4         1  19       1          35
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width  ram  sc_h  sc_w  \
# 1705    0.3        110        4  ...        405       742  879    16     2
#
#       talk_time  three_g  touch_screen  wifi  price_range
# 1705          8        1             0     0            0
#
# [1 rows x 21 columns]

# %%
df[df['fc']==df['fc'].min()]
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1              1021     1          0.5         1   0       1          53
# 3               615     1          2.5         0   0       0          10
# 7              1954     0          0.5         1   0       0          24
# 8              1445     1          0.5         0   0       0          53
# 10              769     1          2.9         1   0       0           9
# ...             ...   ...          ...       ...  ..     ...         ...
# 1971            538     0          1.1         1   0       1          25
# 1984            797     0          2.2         1   0       0          37
# 1993           1467     1          0.5         0   0       0          18
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
import numpy as np

# %%
values = ['Low', 'Mid', 'High']

conditions = [
    (df['clock_speed'] <= 1),
    (df['clock_speed'] > 1) & (df['clock_speed'] < 2),
    (df['clock_speed'] >= 2)
]

df['clock_rate'] = np.select(conditions, values)
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_width   ram  sc_h  sc_w  talk_time  \
# ...

# %%
plot = sns.heatmap(df.corr(numeric_only=True), cmap='PiYG', annot=True, linewidths=0.2)

# %%
plt.hist(df.battery_power)
# Out:
# (array([223., 199., 210., 199., 190., 185., 193., 201., 197., 203.]),
#  array([ 501. ,  650.7,  800.4,  950.1, 1099.8, 1249.5, 1399.2, 1548.9,
#         1698.6, 1848.3, 1998. ]),
#  <BarContainer object of 10 artists>)
